# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.random.randint(1,30,(15,1))
df=pd.DataFrame(data)
df
df.to_csv('input.csv')
print(df)
# Out:
#      0
# 0   11
# 1   24
# 2    6
# 3   12
# 4   11
# 5    8
# 6   24
# 7    6
# 8    6
# 9   17
# 10  11
# 11  25
# 12  14
# 13  21
# 14  10

# %%
inputs=pd.read_csv('input.csv',index_col=0)
inputs.plot()
plt.legend(['input'])
plt.show()

# %%
def RNN(x,weights,bias):
    x=tf.reshape(x,[-1,n_input])
    run_cell=run.BasicLstmcell(n_hidden)
    outputs,states=run.static_run(run_cell,x,dtype=tf.float32)
    return tf.matmul(outputs[-1],weights['out'],bias['out'])
